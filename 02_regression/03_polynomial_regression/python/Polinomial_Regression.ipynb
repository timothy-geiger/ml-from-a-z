# %% [markdown]
# # Polinomial Regression
#
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import the Dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
dataset.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %% [markdown]
# ## Split the Dataset

# %%
from sklearn.model_selection import train_test_split

y = dataset['Salary']
X = dataset.drop(['Position', 'Salary'], axis=1)

# %% [markdown]
# ## Train with a Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Train with the Polinomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

pf = PolynomialFeatures(degree=4)
X_poly = pf.fit_transform(X)

lr_poly = LinearRegression()
lr_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualize

# %%
plt.scatter(X, y, color='red')
plt.plot(X, lr.predict(X), color='blue')
plt.title('Truth of Bluff (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X, y, color='red')
plt.plot(X, lr_poly.predict(X_poly), color='blue')
plt.title('Truth of Bluff (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Evaluate new sample

# %%
lr.predict([[6.5]])
# Out:
# /Users/Timothy/miniforge3/envs/irp/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([330378.78787879])

# %%
lr_poly.predict(pf.fit_transform([[6.5]]))
# Out:
# array([158862.45265152])
